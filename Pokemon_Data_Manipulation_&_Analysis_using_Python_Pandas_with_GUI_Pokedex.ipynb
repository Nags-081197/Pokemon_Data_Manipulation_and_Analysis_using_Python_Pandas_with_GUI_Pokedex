# %%
# This file consists of Pokemon Data Reading, Manipulating, Filtering, Searching and Analysis.
# Also provides a GUI Pokedex to visualize pokemon information

# %%
#importing pandas
import pandas as pd

# %%
# loadig data from csv
dataframe = pd.read_csv('pokemon_data.csv')
dataframe
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#retrieve only specified number of rows from the the top
dataframe.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
#retrieve only specified number of rows from the the bottom
dataframe.tail(3)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
#retrieve column names
dataframe.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#retrieve only a specific coulmn information
dataframe['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
#retrieve only a specific coulmns information
dataframe[['Name','Attack']]
# Out:
#                       Name  Attack
# 0                Bulbasaur      49
# 1                  Ivysaur      62
# 2                 Venusaur      82
# 3    VenusaurMega Venusaur     100
# 4               Charmander      52
# ..                     ...     ...
# 795                Diancie     100
# 796    DiancieMega Diancie     160
# 797    HoopaHoopa Confined     110
# 798     HoopaHoopa Unbound     160
# 799              Volcanion     110
#
# [800 rows x 2 columns]

# %%
# iloc - integer location function  - Alternatively to retrieve specifi rows of data
dataframe.iloc[0]
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
dataframe.iloc[0:4]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
# using iloc to get specifi element in a specific row
dataframe.iloc[0][1]
# Out:
# 'Bulbasaur'

# %%
# to iterate through rows
for i, row in dataframe.iterrows():
    print(i, row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
# loc function to lookup data by its text value (not only index like iloc)
dataframe.loc[dataframe['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# to retrieve useful info like Mean etc.
dataframe.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
# Sorting rows in the dataframe
dataframe.sort_values(['Name'], ascending = False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
dataframe.sort_values(['Type 1', 'HP'], ascending = [True, False])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# to make new columns
dataframe['Total'] = dataframe.iloc[:,4:10].sum(axis=1)
dataframe
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
cols = list(dataframe.columns)
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
# rearranging columns and saving new data
dataframe = dataframe[cols[0:4] + [cols[-1]] + cols[4:12]]
dataframe
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# to save to csv - modified pokemon data
dataframe.to_csv('modified_pokemon_data.csv', index=False)

# %%
dataframe.loc[ ((dataframe['Type 1'] == 'Grass') | (dataframe['Type 2'] == 'Poison') ) & (dataframe['HP'] > 70)]
# Out:
#        #                     Name Type 1    Type 2  Total   HP  Attack  \
# 2      3                 Venusaur  Grass    Poison    525   80      82
# 3      3    VenusaurMega Venusaur  Grass    Poison    625   80     100
# 50    45                Vileplume  Grass    Poison    490   75      80
# 77    71               Victreebel  Grass    Poison    490   80     105
# 79    73               Tentacruel  Water    Poison    515   80      70
# 111  103                Exeggutor  Grass   Psychic    520   95      95
# 168  154                 Meganium  Grass       NaN    525   80      82
# 197  182                Bellossom  Grass       NaN    490   75      80
# 204  189                 Jumpluff  Grass    Flying    460   75      55
# 207  192                 Sunflora  Grass       NaN    425   75      75
# 298  275                  Shiftry  Grass      Dark    480   90     100
# 390  357                  Tropius  Grass    Flying    460   99      68
# ...

# %%
new_dataframe = dataframe.loc[ ((dataframe['Type 1'] == 'Grass') | (dataframe['Type 2'] == 'Poison') ) & (dataframe['HP'] > 70)]

new_dataframe.reset_index(drop = True)
# Out:
#       #                     Name Type 1    Type 2  Total   HP  Attack  \
# 0     3                 Venusaur  Grass    Poison    525   80      82
# 1     3    VenusaurMega Venusaur  Grass    Poison    625   80     100
# 2    45                Vileplume  Grass    Poison    490   75      80
# 3    71               Victreebel  Grass    Poison    490   80     105
# 4    73               Tentacruel  Water    Poison    515   80      70
# 5   103                Exeggutor  Grass   Psychic    520   95      95
# 6   154                 Meganium  Grass       NaN    525   80      82
# 7   182                Bellossom  Grass       NaN    490   75      80
# 8   189                 Jumpluff  Grass    Flying    460   75      55
# 9   192                 Sunflora  Grass       NaN    425   75      75
# 10  275                  Shiftry  Grass      Dark    480   90     100
# 11  357                  Tropius  Grass    Flying    460   99      68
# ...

# %%
# to is string contains another string

dataframe.loc[dataframe['Name'].str.contains('Mega')]

# negation using tilde ~
#dataframe.loc[~dataframe['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318   45      49       49
# 1      2              Ivysaur    Grass  Poison    405   60      62       63
# 2      3             Venusaur    Grass  Poison    525   80      82       83
# 4      4           Charmander     Fire     NaN    309   39      52       43
# 5      5           Charmeleon     Fire     NaN    405   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# using Regex to filter data
import re

# setting flags to ignore case
dataframe.loc[dataframe['Type 1'].str.contains('fire|grass', flags = re.I, regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 4      4             Charmander   Fire     NaN    309   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    369   62      50       58
# 736  668                 Pyroar   Fire  Normal    507   86      68       72
# 740  672                 Skiddo  Grass     NaN    350   66      65       48
# 741  673                 Gogoat  Grass     NaN    531  123     100       62
# 799  721              Volcanion   Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
dataframe.loc[dataframe['Name'].str.contains('^pi[a-z]*', flags = re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying    251   40      45
# 21    17            Pidgeotto    Normal    Flying    349   63      60
# 22    18              Pidgeot    Normal    Flying    479   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 30    25              Pikachu  Electric       NaN    320   35      55
# 136  127               Pinsir       Bug       NaN    500   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying    600   65     155
# 186  172                Pichu  Electric       NaN    205   20      40
# 219  204               Pineco       Bug       NaN    290   50      65
# 239  221            Piloswine       Ice    Ground    450  100     100
# 438  393               Piplup     Water       NaN    314   53      51
# 558  499              Pignite      Fire  Fighting    418   90      93
# ...

# %%
#to change present values in the current dataframe with something useful
dataframe.loc[dataframe['Type 1'] == 'Fire'] = 'Flamer'
dataframe
# Out:
#           #                   Name   Type 1  Type 2   Total      HP  Attack  \
# 0         1              Bulbasaur    Grass  Poison     318      45      49
# 1         2                Ivysaur    Grass  Poison     405      60      62
# 2         3               Venusaur    Grass  Poison     525      80      82
# 3         3  VenusaurMega Venusaur    Grass  Poison     625      80     100
# 4    Flamer                 Flamer   Flamer  Flamer  Flamer  Flamer  Flamer
# ..      ...                    ...      ...     ...     ...     ...     ...
# 795     719                Diancie     Rock   Fairy     600      50     100
# 796     719    DiancieMega Diancie     Rock   Fairy     700      50     160
# 797     720    HoopaHoopa Confined  Psychic   Ghost     600      80     110
# 798     720     HoopaHoopa Unbound  Psychic    Dark     680      80     160
# 799  Flamer                 Flamer   Flamer  Flamer  Flamer  Flamer  Flamer
#
#     Defense Sp. Atk Sp. Def   Speed Generation Legendary
# ...

# %%
dataframe.loc[dataframe['Type 1'] == 'Flamer'] = 'Fire'
dataframe
# Out:
#         #                   Name   Type 1  Type 2 Total    HP Attack Defense  \
# 0       1              Bulbasaur    Grass  Poison   318    45     49      49
# 1       2                Ivysaur    Grass  Poison   405    60     62      63
# 2       3               Venusaur    Grass  Poison   525    80     82      83
# 3       3  VenusaurMega Venusaur    Grass  Poison   625    80    100     123
# 4    Fire                   Fire     Fire    Fire  Fire  Fire   Fire    Fire
# ..    ...                    ...      ...     ...   ...   ...    ...     ...
# 795   719                Diancie     Rock   Fairy   600    50    100     150
# 796   719    DiancieMega Diancie     Rock   Fairy   700    50    160     110
# 797   720    HoopaHoopa Confined  Psychic   Ghost   600    80    110      60
# 798   720     HoopaHoopa Unbound  Psychic    Dark   680    80    160      60
# 799  Fire                   Fire     Fire    Fire  Fire  Fire   Fire    Fire
#
# ...

# %%
# checking in a specific column and editing different column
dataframe.loc[dataframe['Type 1'] == 'Fire', 'Legendary' ] = 'True'
dataframe
# Out:
#         #                   Name   Type 1  Type 2 Total    HP Attack Defense  \
# 0       1              Bulbasaur    Grass  Poison   318    45     49      49
# 1       2                Ivysaur    Grass  Poison   405    60     62      63
# 2       3               Venusaur    Grass  Poison   525    80     82      83
# 3       3  VenusaurMega Venusaur    Grass  Poison   625    80    100     123
# 4    Fire                   Fire     Fire    Fire  Fire  Fire   Fire    Fire
# ..    ...                    ...      ...     ...   ...   ...    ...     ...
# 795   719                Diancie     Rock   Fairy   600    50    100     150
# 796   719    DiancieMega Diancie     Rock   Fairy   700    50    160     110
# 797   720    HoopaHoopa Confined  Psychic   Ghost   600    80    110      60
# 798   720     HoopaHoopa Unbound  Psychic    Dark   680    80    160      60
# 799  Fire                   Fire     Fire    Fire  Fire  Fire   Fire    Fire
#
# ...

# %%
# getting back the checkpoint values
dataframe = pd.read_csv('modified_pokemon_data.csv')
dataframe
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
dataframe.loc[dataframe['Total']>500, ['Generation', 'Legendary']] = ['Test1', 'Test2']
dataframe
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# Aggregation and Statistics

# getting back the checkpoint values
dataframe = pd.read_csv('modified_pokemon_data.csv')

dataframe.groupby(['Type 1']).mean().sort_values('Defense', ascending=False)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Steel     442.851852  487.703704  65.222222   92.703704  126.370370
# Rock      392.727273  453.750000  65.363636   92.863636  100.795455
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Psychic   380.807018  475.947368  70.631579   71.456140   67.684211
# ...

# %%
dataframe.groupby(['Type 1']).sum().sort_values('Defense', ascending=False)
# Out:
#               #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Water     33946  48211  8071    8305     8170     8379     7898   7388
# Normal    31279  39365  7573    7200     5865     5470     6245   7012
# Grass     24141  29480  4709    5125     4956     5425     4930   4335
# Bug       23080  26146  3925    4897     4880     3717     4471   4256
# Rock      17280  19965  2876    4086     4435     2787     3321   2460
# Psychic   21706  27129  4026    4073     3858     5609     4918   4645
# Fire      17025  23820  3635    4408     3524     4627     3755   3871
# Steel     11957  13168  1761    2503     3412     1823     2177   1492
# Electric  15994  19510  2631    3040     2917     3961     3243   3718
# Dragon    15180  17617  2666    3588     2764     3099     2843   2657
# Ground    11401  14000  2361    3064     2715     1807     2008   2045
# Ghost     15568  14066  2062    2361     2598     2539     2447   2059
# ...

# %%
dataframe.groupby(['Type 1', 'Type 2']).count().sort_values('Defense', ascending=False)['#']
# Out:
# Type 1    Type 2
# Normal    Flying    24
# Grass     Poison    15
# Bug       Flying    14
#           Poison    12
# Ghost     Grass     10
#                     ..
# Fire      Rock       1
# Ice       Ghost      1
# Fire      Dragon     1
# Fighting  Flying     1
# Water     Steel      1
# Name: #, Length: 136, dtype: int64

# %%
# working with large datasets
dataframe = pd.read_csv('modified_pokemon_data.csv', chunksize = 5 )
dataframe

# %%
for dataframe in pd.read_csv('modified_pokemon_data.csv', chunksize = 800 ):
    print(dataframe)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
new_dataframe = pd.DataFrame(columns = dataframe.columns)

for df in pd.read_csv('modified_pokemon_data.csv', chunksize = 5 ):
    res = df.groupby(['Type 1']).count()
    new_dataframe = pd.concat([new_dataframe, res])

# %%
# To search POKEDEX RUN the next two cells and Enter valid pokemon name

# %%
import urllib.request
from PIL import Image, ImageTk
import tkinter as tk
import re
import pandas as pd

# %%
# pokedex modelling

def pokemonCard(data,ind):
    url = 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/'+ str(data['#'][ind])+'.png'
    urllib.request.urlretrieve(url,"card_img.png")
    img = Image.open("card_img.png")
    
    # Tkinter
    root = tk.Tk()
    root.title("Pokedex")
    
    canvas = tk.Canvas(root, width = 350, height = 150)
    canvas.grid(columnspan = 3)
    
    #pokemon image 
    pokemon_img = Image.open("card_img.png")
    pokemon_img = ImageTk.PhotoImage(pokemon_img)
    pokemon_img_label = tk.Label(root,image = pokemon_img)
    pokemon_img_label.image = pokemon_img
    pokemon_img_label.grid(column = 1, row = 0)
    
    #pokemon information 
    Pokedex_Number_label = tk.Label(root, text =  "Pokedex No -")
    Pokedex_Number_label.grid(columnspan = 2, column = 0, row = 1)
    
    Pokedex_Number = tk.Label(root, text =str(data['#'][ind]))
    Pokedex_Number.grid(columnspan = 2, column = 1, row = 1)
    
    
    Pokedex_Name_out = tk.Label(root, text = "Name -")
    Pokedex_Name_out.grid(columnspan = 2, column = 0, row = 2)
    
    Pokedex_Name = tk.Label(root, text = str(data['Name'][ind]))
    Pokedex_Name.grid(columnspan = 2, column = 1, row = 2)
    
    
    Pokedex_type1_out = tk.Label(root, text = "Type 1 -")
    Pokedex_type1_out.grid(columnspan = 2, column = 0, row = 3)
    
    Pokedex_type1 = tk.Label(root, text = str(data['Type 1'][ind]))
    Pokedex_type1.grid(columnspan = 2, column = 1, row = 3)
    
    
    Pokedex_type2_out = tk.Label(root, text = "Type 2 -")
    Pokedex_type2_out.grid(columnspan = 2, column = 0, row = 4)
    
    Pokedex_type2 = tk.Label(root, text =str(data['Type 2'][ind]))
    Pokedex_type2.grid(columnspan = 2, column = 1, row = 4)
    
    
    Pokedex_hp_out = tk.Label(root, text = "HP -")
    Pokedex_hp_out.grid(columnspan = 2, column = 0, row = 5)
    
    Pokedex_hp = tk.Label(root, text =str(data['HP'][ind]))
    Pokedex_hp.grid(columnspan = 2, column = 1,row = 5)
    
    
    Pokedex_attack_out = tk.Label(root, text = "Attack -")
    Pokedex_attack_out.grid(columnspan = 2, column = 0, row = 6)
    
    Pokedex_attack = tk.Label(root, text = str(data['Attack'][ind]))
    Pokedex_attack.grid(columnspan = 2, column = 1, row = 6)
    
    
    Pokedex_defense_out = tk.Label(root, text = "Defense -")
    Pokedex_defense_out.grid(columnspan = 2, column = 0, row = 7)
    
    Pokedex_defense = tk.Label(root, text = str(data['Defense'][ind]))
    Pokedex_defense.grid(columnspan = 2, column = 1, row = 7)
    
    
    Pokedex_splatk_out = tk.Label(root, text = "Sp. Atk -")
    Pokedex_splatk_out.grid(columnspan = 2, column = 0, row = 8)
    
    Pokedex_splatk = tk.Label(root, text = str(data['Sp. Atk'][ind]))
    Pokedex_splatk.grid(columnspan = 2, column = 1, row = 8)
    
    
    Pokedex_spldef_out = tk.Label(root, text = "Sp. Def -")
    Pokedex_spldef_out.grid(columnspan = 2, column = 0, row = 9)
    
    Pokedex_spldef = tk.Label(root, text = str(data['Sp. Def'][ind]))
    Pokedex_spldef.grid(columnspan = 2, column = 1, row = 9)
    
    
    Pokedex_speed_out = tk.Label(root, text = "Speed -")
    Pokedex_speed_out.grid(columnspan = 2, column = 0, row = 10)
    
    Pokedex_speed = tk.Label(root, text = str(data['Speed'][ind]))
    Pokedex_speed.grid(columnspan = 2, column = 1, row = 10)
    
    
    Pokedex_Generation_out = tk.Label(root, text = "Generation -")
    Pokedex_Generation_out.grid(columnspan = 2, column = 0, row = 11)
    
    Pokedex_Generation = tk.Label(root, text = str(data['Generation'][ind]))
    Pokedex_Generation.grid(columnspan = 2, column = 1, row = 11)
    
    
    Pokedex_Legendary_out = tk.Label(root, text = "Legendary -")
    Pokedex_Legendary_out.grid(columnspan = 2, column = 0, row = 12)
    
    Pokedex_Legendary = tk.Label(root, text = str(data['Legendary'][ind]))
    Pokedex_Legendary.grid(columnspan = 2, column = 1, row = 12)
    
    Pokedex_space= tk.Label(root, text = " ")
    Pokedex_space.grid(columnspan = 3, column = 0, row = 14)

    root.mainloop()
    
    
    
    


dataframe = pd.read_csv('modified_pokemon_data.csv')

pokemon_name = input("Enter Pokemon Name : ").strip()

new_df = dataframe.loc[dataframe['Name'].str.contains(pokemon_name, flags = re.I, regex=True)]

if not new_df.empty:
    ind = dataframe.loc[dataframe['Name'].str.contains(pokemon_name, flags = re.I, regex=True)].index[0]
    pokemonCard(new_df,ind)
else:
    print('Pokemon not present in dataset')
# Out:
# Enter Pokemon Name : Charmander
